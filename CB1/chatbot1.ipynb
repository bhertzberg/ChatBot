# %%
from google.colab import drive
drive.mount('/content/drive')
data_root = '/content/drive/My Drive/Colab Notebooks/Chatbot'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import string
import random

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data_file = open(data_root + '/intents2.json').read()
data = json.loads(data_file)

# %%
words = [] #pattern vocab
classes= [] #tag vocab
data_x = [] #store patterns
data_y = [] # store tag for each pattern

for intent in data['intents']:
  for pattern in intent['patterns']:
    tokens = nltk.word_tokenize(pattern)
    words.extend(tokens)
    data_x.append(pattern)
    data_y.append(intent['tag'])

    if intent['tag'] not in classes:
      classes.append(intent['tag'])

# %%
lemmatizer = WordNetLemmatizer()

words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]

words = sorted(set(words))
classes = sorted(set(classes))

# %%
training = []
out_empty = [0]*len(classes)
for idx, doc in enumerate(data_x):
  bow = []
  text = lemmatizer.lemmatize(doc.lower())
  for word in words:
    bow.append(1) if word in text else bow.append(0)

  output_row = list(out_empty)
  output_row[classes.index(data_y[idx])]=1
  training.append([bow, output_row])

random.shuffle(training)
training = np.array(training, dtype = object)

train_x = np.array(list(training[:,0]))
train_y = np.array(list(training[:,1]))

# %%
model = Sequential()
model.add(Dense(128, input_shape =(len(train_x[0]),), activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation = 'softmax'))
adam = tf.keras.optimizers.legacy.Adam(learning_rate = 0.01, decay = 1e-6)
model.compile(loss = 'categorical_crossentropy',
              optimizer = adam,
              metrics = ['accuracy'])
print(model.summary())
model.fit(x = train_x, y = train_y, epochs = 150, verbose = 1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               12928
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 20)                1300
#
# =================================================================
# Total params: 22484 (87.83 KB)
# Trainable params: 22484 (87.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/150
# 2/2 [==============================] - 1s 15ms/step - loss: 3.0344 - accuracy: 0.0794
# Epoch 2/150
# 2/2 [==============================] - 0s 10ms/step - loss: 2.8753 - accuracy: 0.1587
# Epoch 3/150
# 2/2 [==============================] - 0s 8ms/step - loss: 2.8155 - accuracy: 0.1111
# Epoch 4/150
# 2/2 [==============================] - 0s 8ms/step - loss: 2.6586 - accuracy: 0.2222
# Epoch 5/150
# 2/2 [==============================] - 0s 8ms/step - loss: 2.4515 - accuracy: 0.3175
# Epoch 6/150
# 2/2 [==============================] - 0s 8ms/step - loss: 2.4236 - accuracy: 0.2540
# Epoch 7/150
# 2/2 [==============================] - 0s 8ms/step - loss: 2.2283 - accuracy: 0.3968
# Epoch 8/150
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0343 - accuracy: 0.3968
# Epoch 9/150
# 2/2 [==============================] - 0s 8ms/step - loss: 1.7534 - accuracy: 0.5238
# Epoch 10/150
# 2/2 [==============================] - 0s 7ms/step - loss: 1.9223 - accuracy: 0.3651
# Epoch 11/150
# 2/2 [==============================] - 0s 8ms/step - loss: 1.4555 - accuracy: 0.6032
# Epoch 12/150
# 2/2 [==============================] - 0s 8ms/step - loss: 1.4408 - accuracy: 0.5556
# Epoch 13/150
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2398 - accuracy: 0.6825
# Epoch 14/150
# 2/2 [==============================] - 0s 9ms/step - loss: 1.3158 - accuracy: 0.6349
# Epoch 15/150
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0334 - accuracy: 0.7143
# Epoch 16/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9755 - accuracy: 0.7143
# Epoch 17/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8108 - accuracy: 0.6825
# Epoch 18/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8002 - accuracy: 0.8095
# Epoch 19/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6641 - accuracy: 0.7460
# Epoch 20/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6839 - accuracy: 0.8254
# Epoch 21/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4956 - accuracy: 0.9048
# Epoch 22/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4652 - accuracy: 0.8571
# Epoch 23/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4860 - accuracy: 0.8571
# Epoch 24/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6272 - accuracy: 0.8095
# Epoch 25/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4882 - accuracy: 0.8413
# Epoch 26/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4302 - accuracy: 0.8571
# Epoch 27/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2420 - accuracy: 0.9841
# Epoch 28/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2900 - accuracy: 0.9206
# Epoch 29/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2872 - accuracy: 0.9206
# Epoch 30/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3479 - accuracy: 0.9048
# Epoch 31/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2318 - accuracy: 0.9524
# Epoch 32/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4734 - accuracy: 0.8889
# Epoch 33/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2976 - accuracy: 0.8571
# Epoch 34/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3816 - accuracy: 0.8889
# Epoch 35/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1556 - accuracy: 0.9683
# Epoch 36/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1993 - accuracy: 0.9524
# Epoch 37/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2472 - accuracy: 0.9206
# Epoch 38/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1738 - accuracy: 0.9365
# Epoch 39/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2136 - accuracy: 0.9206
# Epoch 40/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2070 - accuracy: 0.9524
# Epoch 41/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2311 - accuracy: 0.9524
# Epoch 42/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2672 - accuracy: 0.8889
# Epoch 43/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1972 - accuracy: 0.9365
# Epoch 44/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3084 - accuracy: 0.9206
# Epoch 45/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0935 - accuracy: 0.9841
# Epoch 46/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2320 - accuracy: 0.9365
# Epoch 47/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1339 - accuracy: 0.9841
# Epoch 48/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1261 - accuracy: 0.9683
# Epoch 49/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1236 - accuracy: 0.9683
# Epoch 50/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1236 - accuracy: 0.9524
# Epoch 51/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0844 - accuracy: 0.9841
# Epoch 52/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1049 - accuracy: 0.9683
# Epoch 53/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1313 - accuracy: 0.9365
# Epoch 54/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2500 - accuracy: 0.9048
# Epoch 55/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1441 - accuracy: 0.9524
# Epoch 56/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1908 - accuracy: 0.9524
# Epoch 57/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1179 - accuracy: 0.9841
# Epoch 58/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1554 - accuracy: 0.9683
# Epoch 59/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0750 - accuracy: 1.0000
# Epoch 60/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1181 - accuracy: 0.9683
# Epoch 61/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1199 - accuracy: 0.9683
# Epoch 62/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1060 - accuracy: 0.9683
# Epoch 63/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1697 - accuracy: 0.9206
# Epoch 64/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1003 - accuracy: 0.9683
# Epoch 65/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0650 - accuracy: 0.9841
# Epoch 66/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1628 - accuracy: 0.9206
# Epoch 67/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1019 - accuracy: 0.9683
# Epoch 68/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2470 - accuracy: 0.9206
# Epoch 69/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1633 - accuracy: 0.9365
# Epoch 70/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1186 - accuracy: 0.9683
# Epoch 71/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1160 - accuracy: 0.9841
# Epoch 72/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1007 - accuracy: 0.9524
# Epoch 73/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0811 - accuracy: 0.9683
# Epoch 74/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0954 - accuracy: 0.9683
# Epoch 75/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1258 - accuracy: 0.9524
# Epoch 76/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0818 - accuracy: 0.9841
# Epoch 77/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1340 - accuracy: 0.9524
# Epoch 78/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0827 - accuracy: 0.9841
# Epoch 79/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1492 - accuracy: 0.9524
# Epoch 80/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0628 - accuracy: 0.9841
# Epoch 81/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1253 - accuracy: 0.9524
# Epoch 82/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0881 - accuracy: 0.9524
# Epoch 83/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0862 - accuracy: 0.9524
# Epoch 84/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0849 - accuracy: 0.9841
# Epoch 85/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0867 - accuracy: 0.9841
# Epoch 86/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0737 - accuracy: 0.9841
# Epoch 87/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0669 - accuracy: 0.9841
# Epoch 88/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0401 - accuracy: 0.9841
# Epoch 89/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0484 - accuracy: 1.0000
# Epoch 90/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1262 - accuracy: 0.9524
# Epoch 91/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1191 - accuracy: 0.9524
# Epoch 92/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1735 - accuracy: 0.9365
# Epoch 93/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1107 - accuracy: 0.9683
# Epoch 94/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0634 - accuracy: 0.9683
# Epoch 95/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0919 - accuracy: 0.9524
# Epoch 96/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0920 - accuracy: 0.9683
# Epoch 97/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0557 - accuracy: 0.9841
# Epoch 98/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0600 - accuracy: 0.9841
# Epoch 99/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1577 - accuracy: 0.9524
# Epoch 100/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1032 - accuracy: 0.9841
# Epoch 101/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2213 - accuracy: 0.9048
# Epoch 102/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0886 - accuracy: 0.9524
# Epoch 103/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1331 - accuracy: 0.9683
# Epoch 104/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0463 - accuracy: 0.9683
# Epoch 105/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0580 - accuracy: 1.0000
# Epoch 106/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0934 - accuracy: 0.9683
# Epoch 107/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1275 - accuracy: 0.9683
# Epoch 108/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0668 - accuracy: 0.9841
# Epoch 109/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0609 - accuracy: 0.9841
# Epoch 110/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1074 - accuracy: 0.9841
# Epoch 111/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0836 - accuracy: 0.9683
# Epoch 112/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1299 - accuracy: 0.9683
# Epoch 113/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1087 - accuracy: 0.9683
# Epoch 114/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0933 - accuracy: 0.9683
# Epoch 115/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1296 - accuracy: 0.9524
# Epoch 116/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0890 - accuracy: 0.9683
# Epoch 117/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0569 - accuracy: 0.9841
# Epoch 118/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1302 - accuracy: 0.9841
# Epoch 119/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 120/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0360 - accuracy: 0.9841
# Epoch 121/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0700 - accuracy: 0.9841
# Epoch 122/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1387 - accuracy: 0.9524
# Epoch 123/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0748 - accuracy: 0.9683
# Epoch 124/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0739 - accuracy: 0.9841
# Epoch 125/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0866 - accuracy: 0.9524
# Epoch 126/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1166 - accuracy: 0.9365
# Epoch 127/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0392 - accuracy: 0.9841
# Epoch 128/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 129/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0655 - accuracy: 0.9841
# Epoch 130/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 131/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1522 - accuracy: 0.9365
# Epoch 132/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0586 - accuracy: 0.9841
# Epoch 133/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0769 - accuracy: 0.9524
# Epoch 134/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0907 - accuracy: 0.9683
# Epoch 135/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 136/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0382 - accuracy: 0.9841
# Epoch 137/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 138/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 139/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0258 - accuracy: 0.9841
# Epoch 140/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0352 - accuracy: 0.9841
# Epoch 141/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0863 - accuracy: 0.9683
# Epoch 142/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0496 - accuracy: 0.9841
# Epoch 143/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0351 - accuracy: 0.9841
# Epoch 144/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0497 - accuracy: 0.9841
# Epoch 145/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0507 - accuracy: 0.9841
# Epoch 146/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0881 - accuracy: 0.9683
# Epoch 147/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 148/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0693 - accuracy: 0.9841
# Epoch 149/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0365 - accuracy: 0.9841
# Epoch 150/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0413 - accuracy: 0.9841

# %%
def clean_text(text):
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text,vocab):
  tokens = clean_text(text)
  bow = [0]*len(vocab)
  for w in tokens:
    for idx, word in enumerate(vocab):
      if word == w:
        bow[idx] = 1
  return np.array(bow)

# %%
def pred_class(text, vocab, labels):
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0]
  thresh = 0.5
  y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
  y_pred.sort(key = lambda x: x[1], reverse = True)
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]])
  return return_list

def get_response(intents_list, intents_json):
  if len(intents_list) == 0:
    result = "Sorry! I don't understand."
  else:
    tag = intents_list[0]
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
      if i['tag'] == tag:
        result = random.choice(i['responses'])
        break
    return result

# %%
#interact with the chatbot
print("Press 0 if you don't want to chat with our Chatbot")
while True:
  message = input("")
  if message == '0':
    break
  intents = pred_class(message, words, classes)
  result = get_response(intents, data)
  print(result)
# Out:
# Press 0 if you don't want to chat with our Chatbot
# what can i ask yo
# 1/1 [==============================] - 0s 141ms/step
# I provide basic info about Ben's background, experience, and interests.
# what is your background
# 1/1 [==============================] - 0s 21ms/step
# I graduated with honors from UCSB in 2023 as a statistics and data science major with a minor in physics.
# what did you learn in physics
# 1/1 [==============================] - 0s 19ms/step
# None
# physics
# 1/1 [==============================] - 0s 31ms/step
# I pursued a minor in physics at UCSB, and hoping to dive deeper in the subject, I joined the UCSB Experimental Cosmology Group, a lunar tech lab in the physics department. Over the next two years, I bounced between the team’s many different projects, including conducting electronics testing for a solar powered rover, running ROSbot simulations using Rviz, creating python simulations of a laser communications system, analyzing data from a thermally insulated battery in a cryogenic chamber, and more. In 2022, our thermally insulated battery design was accepted into the NASA MINDS competition. The team was selected as a finalist, and I was one of the members chosen to present our findings to a team of NASA engineers.
# 0
