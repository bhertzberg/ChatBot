# %%
from google.colab import drive
drive.mount('/content/drive')
data_root = '/content/drive/My Drive/Colab Notebooks/Chatbot'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import string
import random

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data_file = open(data_root + '/intents.json').read()
data = json.loads(data_file)

# %%
words = [] #pattern vocab
classes= [] #tag vocab
data_x = [] #store patterns
data_y = [] # store tag for each pattern

for intent in data['intents']:
  for pattern in intent['patterns']:
    tokens = nltk.word_tokenize(pattern)
    words.extend(tokens)
    data_x.append(pattern)
    data_y.append(intent['tag'])

    if intent['tag'] not in classes:
      classes.append(intent['tag'])

# %%
lemmatizer = WordNetLemmatizer()

words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]

words = sorted(set(words))
classes = sorted(set(classes))

# %%
training = []
out_empty = [0]*len(classes)
for idx, doc in enumerate(data_x):
  bow = []
  text = lemmatizer.lemmatize(doc.lower())
  for word in words:
    bow.append(1) if word in text else bow.append(0)

  output_row = list(out_empty)
  output_row[classes.index(data_y[idx])]=1
  training.append([bow, output_row])

random.shuffle(training)
training = np.array(training, dtype = object)

train_x = np.array(list(training[:,0]))
train_y = np.array(list(training[:,1]))

# %%
model = Sequential()
model.add(Dense(128, input_shape =(len(train_x[0]),), activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation = 'softmax'))
adam = tf.keras.optimizers.legacy.Adam(learning_rate = 0.01, decay = 1e-6)
model.compile(loss = 'categorical_crossentropy',
              optimizer = adam,
              metrics = ['accuracy'])
print(model.summary())
model.fit(x = train_x, y = train_y, epochs = 150, verbose = 1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               7552
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 15)                975
#
# =================================================================
# Total params: 16783 (65.56 KB)
# Trainable params: 16783 (65.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/150
# 2/2 [==============================] - 2s 19ms/step - loss: 2.7662 - accuracy: 0.0488
# Epoch 2/150
# 2/2 [==============================] - 0s 16ms/step - loss: 2.5791 - accuracy: 0.2439
# Epoch 3/150
# 2/2 [==============================] - 0s 12ms/step - loss: 2.5705 - accuracy: 0.2439
# Epoch 4/150
# 2/2 [==============================] - 0s 11ms/step - loss: 2.3987 - accuracy: 0.3415
# Epoch 5/150
# 2/2 [==============================] - 0s 13ms/step - loss: 2.2673 - accuracy: 0.3415
# Epoch 6/150
# 2/2 [==============================] - 0s 14ms/step - loss: 2.1196 - accuracy: 0.4146
# Epoch 7/150
# 2/2 [==============================] - 0s 13ms/step - loss: 1.9448 - accuracy: 0.3902
# Epoch 8/150
# 2/2 [==============================] - 0s 12ms/step - loss: 1.6759 - accuracy: 0.5366
# Epoch 9/150
# 2/2 [==============================] - 0s 10ms/step - loss: 1.8202 - accuracy: 0.4390
# Epoch 10/150
# 2/2 [==============================] - 0s 12ms/step - loss: 1.3213 - accuracy: 0.7317
# Epoch 11/150
# 2/2 [==============================] - 0s 11ms/step - loss: 1.3641 - accuracy: 0.5366
# Epoch 12/150
# 2/2 [==============================] - 0s 12ms/step - loss: 1.2236 - accuracy: 0.6829
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0826 - accuracy: 0.9756
# Epoch 113/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2217 - accuracy: 0.9268
# Epoch 114/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0761 - accuracy: 0.9756
# Epoch 115/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0507 - accuracy: 0.9756
# Epoch 116/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1395 - accuracy: 0.9512
# Epoch 117/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2268 - accuracy: 0.8780
# Epoch 118/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0791 - accuracy: 0.9756
# Epoch 119/150
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1514 - accuracy: 0.9512
# Epoch 120/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0780 - accuracy: 0.9756
# Epoch 121/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1045 - accuracy: 1.0000
# Epoch 122/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0730 - accuracy: 0.9756
# Epoch 123/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0839 - accuracy: 0.9756
# Epoch 124/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1521 - accuracy: 0.9756
# Epoch 125/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1864 - accuracy: 0.9024
# Epoch 126/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0659 - accuracy: 0.9756
# Epoch 127/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0855 - accuracy: 0.9756
# Epoch 128/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0512 - accuracy: 1.0000
# Epoch 129/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1035 - accuracy: 0.9512
# Epoch 130/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0407 - accuracy: 0.9756
# Epoch 131/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1541 - accuracy: 0.9268
# Epoch 132/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1293 - accuracy: 0.9024
# Epoch 133/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0853 - accuracy: 0.9512
# Epoch 134/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0703 - accuracy: 0.9512
# Epoch 135/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0396 - accuracy: 0.9756
# Epoch 136/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0463 - accuracy: 0.9756
# Epoch 137/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0916 - accuracy: 1.0000
# Epoch 138/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0477 - accuracy: 1.0000
# Epoch 139/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1678 - accuracy: 0.9268
# Epoch 140/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 141/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0444 - accuracy: 1.0000
# Epoch 142/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0966 - accuracy: 0.9756
# Epoch 143/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0568 - accuracy: 0.9756
# Epoch 144/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 145/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0681 - accuracy: 1.0000
# Epoch 146/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1591 - accuracy: 0.9512
# Epoch 147/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1078 - accuracy: 0.9512
# Epoch 148/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0819 - accuracy: 0.9756
# Epoch 149/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0534 - accuracy: 1.0000
# Epoch 150/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1422 - accuracy: 0.9268

# %%
def clean_text(text):
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text,vocab):
  tokens = clean_text(text)
  bow = [0]*len(vocab)
  for w in tokens:
    for idx, word in enumerate(vocab):
      if word == w:
        bow[idx] = 1
  return np.array(bow)

# %%
def pred_class(text, vocab, labels):
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0]
  thresh = 0.5
  y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
  y_pred.sort(key = lambda x: x[1], reverse = True)
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]])
  return return_list

def get_response(intents_list, intents_json):
  if len(intents_list) == 0:
    result = "Sorry! I don't understand."
  else:
    tag = intents_list[0]
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
      if i['tag'] == tag:
        result = random.choice(i['responses'])
        break
    return result

# %%
#interact with the chatbot
print("Press 0 if you don't want to chat with our Chatbot")
while True:
  message = input("")
  if message == '0':
    break
  intents = pred_class(message, words, classes)
  result = get_response(intents, data)
  print(result)
# Out:
# Press 0 if you don't want to chat with our Chatbot
# hello
# 1/1 [==============================] - 0s 28ms/step
# Hi!
# how are you
# 1/1 [==============================] - 0s 24ms/step
# I am feeling good, you?
# pretty good
# 1/1 [==============================] - 0s 21ms/step
# That is perfect!
# yes it is
# 1/1 [==============================] - 0s 34ms/step
# None
# hello
# 1/1 [==============================] - 0s 21ms/step
# Hey!
# hello
# 1/1 [==============================] - 0s 23ms/step
# Hey!
# hello
# 1/1 [==============================] - 0s 21ms/step
# Good morning!
# morning
# 1/1 [==============================] - 0s 21ms/step
# Hello
# what day is it
# 1/1 [==============================] - 0s 35ms/step
# I work to serve you as well as possible
# who are you
# 1/1 [==============================] - 0s 25ms/step
# I am feeling good, you?
# not bad
# 1/1 [==============================] - 0s 39ms/step
# I hope you will feel better !
# thank you
# 1/1 [==============================] - 0s 33ms/step
# I only do my job️
# thank you
# 1/1 [==============================] - 0s 21ms/step
# I only do my job️
# thank you
# 1/1 [==============================] - 0s 23ms/step
# I only do my job️
# thank you
# 1/1 [==============================] - 0s 37ms/step
# I only do my job️
# whats up
# 1/1 [==============================] - 0s 23ms/step
# Hello
# dog
# 1/1 [==============================] - 0s 22ms/step
# That is perfect!
# yo
# 1/1 [==============================] - 0s 46ms/step
# So, everything's okay!
# yes
# 1/1 [==============================] - 0s 35ms/step
# That is perfect!
# no
# 1/1 [==============================] - 0s 22ms/step
# I hope you will feel better !
# yes
# 1/1 [==============================] - 0s 31ms/step
# That is perfect!
# yes
# 1/1 [==============================] - 0s 26ms/step
# So, everything's okay!
# good
# 1/1 [==============================] - 0s 21ms/step
# That is perfect!
# everything
# 1/1 [==============================] - 0s 37ms/step
# So, everything's okay!
# what can i ask you
# 1/1 [==============================] - 0s 21ms/step
# I can do a lot of things but here are some of my skills, you can ask me: the capital of a country, its currency and its area. A random number. To calculate a math operation.
# whats 10 times 5
# 1/1 [==============================] - 0s 20ms/step
# So, everything's okay!
# whats 10 *
# 1/1 [==============================] - 0s 25ms/step
# So, everything's okay!
# 10 times 5
# 1/1 [==============================] - 0s 33ms/step
# So, everything's okay!
# 10 * 5
# 1/1 [==============================] - 0s 22ms/step
# That is perfect!
# five plus three
# 1/1 [==============================] - 0s 26ms/step
# So, everything's okay!
# 5 + 3
# 1/1 [==============================] - 0s 33ms/step
# That is perfect!
# whats the capital of france
# 1/1 [==============================] - 0s 23ms/step
# So, everything's okay!
# 0
